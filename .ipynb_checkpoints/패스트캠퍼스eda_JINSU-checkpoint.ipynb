# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('/Users/jinsuc28/Documents/GitHub/YearDream2/파이널프로젝트_RAW_210329_210926.xlsx')

# %%
import matplotlib.font_manager as fm
from matplotlib import rc, rcdefaults

font_list = [font.name for font in fm.fontManager.ttflist]
font_list
# Out:
# ['DejaVu Serif',
#  'STIXSizeOneSym',
#  'cmtt10',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Display',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'STIXSizeTwoSym',
#  'cmex10',
#  'STIXSizeThreeSym',
#  'STIXSizeOneSym',
#  'DejaVu Serif Display',
#  'STIXSizeFourSym',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'cmsy10',
#  'cmmi10',
#  'STIXSizeFiveSym',
#  'cmss10',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'STIXSizeThreeSym',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'cmr10',
#  'STIXNonUnicode',
#  'cmb10',
#  'DejaVu Sans',
#  'Noto Sans Linear A',
#  'Hiragino Mincho ProN',
#  'Noto Sans Mro',
#  'Apple Braille',
#  'Arial Narrow',
#  'Bangla Sangam MN',
#  'Trebuchet MS',
#  'Tahoma',
#  'Hiragino Sans',
#  'STIXIntegralsUpSm',
#  '.SF NS Rounded',
#  'Arial',
#  'Lao MN',
#  'PT Serif Caption',
#  'Noto Sans Saurashtra',
#  'Noto Sans Phoenician',
#  'Gurmukhi MN',
#  'Geneva',
#  'Georgia',
#  'Shree Devanagari 714',
#  'STIXSizeTwoSym',
#  'STIXGeneral',
#  'Noto Sans Bassa Vah',
#  'Geeza Pro',
#  'STIXIntegralsUpD',
#  'Noto Sans Modi',
#  'Noto Sans Batak',
#  'Bodoni 72',
#  'Noto Sans Oriya',
#  'Zapf Dingbats',
#  'Noteworthy',
#  'Courier New',
#  'Beirut',
#  'Didot',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'Noto Sans Sora Sompeng',
#  'Devanagari Sangam MN',
#  'Hiragino Sans',
#  'Noto Sans Imperial Aramaic',
#  'Arial Black',
#  'Baskerville',
#  'Farah',
#  'Raanana',
#  'KufiStandardGK',
#  'Euphemia UCAS',
#  'STIXGeneral',
#  'Copperplate',
#  'Futura',
#  'Verdana',
#  'Damascus',
#  'Apple Braille',
#  'Noto Sans Pau Cin Hau',
#  'Arial',
#  'Wingdings',
#  'Brush Script MT',
#  'Georgia',
#  'STIXSizeThreeSym',
#  'Wingdings 2',
#  'Noto Serif Myanmar',
#  'Charter',
#  'Arial Unicode MS',
#  'Lao Sangam MN',
#  'Noto Sans Syloti Nagri',
#  'Noto Sans NKo',
#  'Noto Sans Osmanya',
#  'Courier',
#  'Noto Sans Gunjala Gondi',
#  'Arial',
#  'Noto Sans Kayah Li',
#  'Apple Braille',
#  'STIXNonUnicode',
#  'Gill Sans',
#  'Avenir Next Condensed',
#  'Oriya Sangam MN',
#  'Noto Nastaliq Urdu',
#  'Sinhala MN',
#  'DIN Alternate',
#  'Al Tarikh',
#  'Noto Sans Warang Citi',
#  'Hiragino Sans',
#  'American Typewriter',
#  'Krungthep',
#  'Noto Sans Multani',
#  'Noto Sans Sundanese',
#  'Kefa',
#  'PT Serif',
#  'Noto Sans Kannada',
#  'Noto Sans Cham',
#  'Luminari',
#  'Seravek',
#  'Bodoni 72 Smallcaps',
#  'STIXSizeOneSym',
#  'Trebuchet MS',
#  'Noto Sans Inscriptional Parthian',
#  'STIXSizeThreeSym',
#  'STIXIntegralsD',
#  'Waseem',
#  'STIXSizeFourSym',
#  'Noto Sans Caucasian Albanian',
#  'Hiragino Sans',
#  'PT Mono',
#  'Noto Sans Psalter Pahlavi',
#  'Noto Sans New Tai Lue',
#  'Noto Sans Yi',
#  'Telugu MN',
#  'Arial Narrow',
#  'Microsoft Sans Serif',
#  'STIXSizeTwoSym',
#  'Noto Sans Osage',
#  'ITF Devanagari',
#  'Noto Sans Lydian',
#  'Noto Sans Nabataean',
#  'Noto Sans Gothic',
#  '.SF NS Mono',
#  'Palatino',
#  'Noto Sans Glagolitic',
#  'AppleMyungjo',
#  'Bodoni Ornaments',
#  'Sathu',
#  'Times New Roman',
#  'Diwan Kufi',
#  'Noto Sans Limbu',
#  'Hiragino Sans GB',
#  'STIXIntegralsSm',
#  'Noto Sans Old Persian',
#  'Plantagenet Cherokee',
#  '.SF NS Mono',
#  'Mishafi',
#  'Menlo',
#  'STIXNonUnicode',
#  'Hiragino Sans',
#  'Noto Sans Lepcha',
#  'Noto Sans Old South Arabian',
#  '.New York',
#  'Webdings',
#  'STIXIntegralsSm',
#  'Songti SC',
#  'Hiragino Maru Gothic Pro',
#  'Myanmar MN',
#  'Noto Sans Marchen',
#  'Hoefler Text',
#  'Khmer Sangam MN',
#  'Arial',
#  'Noto Sans Duployan',
#  'Party LET',
#  'Diwan Thuluth',
#  'Noto Serif Balinese',
#  'Malayalam Sangam MN',
#  'Andale Mono',
#  'STIXSizeFourSym',
#  'Noto Sans Coptic',
#  'Noto Sans Mandaic',
#  'Noto Sans Cuneiform',
#  'Noto Sans Inscriptional Pahlavi',
#  'Noto Sans Cypriot',
#  'Noto Sans Brahmi',
#  'Georgia',
#  'Noto Sans Chakma',
#  'Courier New',
#  'Rockwell',
#  'Tamil Sangam MN',
#  'Comic Sans MS',
#  'Noto Sans Lycian',
#  'Kailasa',
#  'Devanagari MT',
#  'Noto Sans Old Hungarian',
#  'Comic Sans MS',
#  'Noto Sans Hanifi Rohingya',
#  'Noto Sans Meetei Mayek',
#  'Farisi',
#  'Optima',
#  'Noto Sans Khudawadi',
#  'Avenir',
#  'Corsiva Hebrew',
#  'Apple Chancery',
#  'Noto Sans Mahajani',
#  'Noto Sans Carian',
#  'AppleGothic',
#  'New Peninim MT',
#  'Apple SD Gothic Neo',
#  '.SF Compact Rounded',
#  'Noto Sans Avestan',
#  'Noto Sans Khojki',
#  'Silom',
#  'Noto Sans Kaithi',
#  'Georgia',
#  'Snell Roundhand',
#  'Gujarati MT',
#  'Noto Sans Tifinagh',
#  'Noto Sans Tagbanwa',
#  'Noto Sans Myanmar',
#  'Hiragino Sans',
#  'Myanmar Sangam MN',
#  'Noto Sans Mende Kikakui',
#  'Noto Sans Newa',
#  'PingFang HK',
#  'Arial Hebrew',
#  '.SF Arabic',
#  'Arial Unicode MS',
#  'Chalkduster',
#  'Superclarendon',
#  'STIXGeneral',
#  'STIXVariants',
#  '.New York',
#  'Cochin',
#  'Noto Serif Ahom',
#  'DecoType Naskh',
#  'Noto Sans Buginese',
#  'Thonburi',
#  'Noto Sans Lisu',
#  'Noto Sans Thaana',
#  'Kokonor',
#  'Noto Sans Tai Viet',
#  'STIXIntegralsD',
#  'STIXIntegralsUpD',
#  'Herculanum',
#  'Mishafi Gold',
#  'Verdana',
#  'Noto Sans Old Turkic',
#  'Helvetica Neue',
#  'Helvetica',
#  'Noto Sans Sharada',
#  'System Font',
#  'Savoye LET',
#  'Noto Sans PhagsPa',
#  'Trebuchet MS',
#  'Al Nile',
#  'Noto Sans Mongolian',
#  'Zapfino',
#  'Skia',
#  'STIXSizeOneSym',
#  'Kohinoor Gujarati',
#  'Times New Roman',
#  '.SF Compact',
#  'Noto Serif Yezidi',
#  'Apple Braille',
#  'Mshtakan',
#  'Gurmukhi MT',
#  'Noto Sans Syriac',
#  'Arial Narrow',
#  'Noto Sans Tai Le',
#  'Courier New',
#  'Noto Sans Rejang',
#  'Noto Sans Old Permic',
#  'Sana',
#  'STIXSizeFiveSym',
#  'Noto Sans Buhid',
#  'STIXNonUnicode',
#  'Symbol',
#  'System Font',
#  'Noto Sans Ugaritic',
#  '.Keyboard',
#  'Hiragino Sans',
#  'Monaco',
#  'Malayalam MN',
#  'Noto Sans Siddham',
#  'Iowan Old Style',
#  'Marker Felt',
#  'Big Caslon',
#  'Sinhala Sangam MN',
#  'Hoefler Text',
#  'Noto Sans Tai Tham',
#  'Noto Sans Elbasan',
#  'Kohinoor Bangla',
#  'Nadeem',
#  'Noto Sans Kharoshthi',
#  'Noto Sans Tirhuta',
#  'Verdana',
#  'Academy Engraved LET',
#  'Kohinoor Telugu',
#  'Noto Sans Hatran',
#  'Hiragino Sans',
#  'Noto Sans Adlam',
#  'Verdana',
#  'Muna',
#  'Chalkboard SE',
#  'Kannada Sangam MN',
#  'Athelas',
#  'Times New Roman',
#  'Khmer MN',
#  'Noto Sans Palmyrene',
#  'Courier New',
#  'Hiragino Sans',
#  'PT Sans',
#  'Baghdad',
#  'Noto Sans Bhaiksuki',
#  'Bangla MN',
#  'Trattatello',
#  'Heiti TC',
#  'Noto Sans Old North Arabian',
#  'Noto Sans Javanese',
#  'Chalkboard',
#  'Papyrus',
#  'Tahoma',
#  'Noto Sans Tagalog',
#  'Bradley Hand',
#  'Impact',
#  'Sukhumvit Set',
#  'Phosphate',
#  'Noto Sans Miao',
#  'Apple Symbols',
#  'Bodoni 72 Oldstyle',
#  'Kohinoor Devanagari',
#  'Galvji',
#  'Noto Sans Ol Chiki',
#  'Al Bayan',
#  'Times New Roman',
#  'STIXVariants',
#  'Noto Sans Samaritan',
#  '.Aqua Kana',
#  'Noto Sans Takri',
#  'SignPainter',
#  'Gurmukhi Sangam MN',
#  'Marion',
#  'Noto Sans Meroitic',
#  'Tamil MN',
#  'Noto Sans Bamum',
#  'Kannada MN',
#  'STIXIntegralsUpSm',
#  'Apple Braille',
#  'Gujarati Sangam MN',
#  'Lucida Grande',
#  'Noto Sans Linear B',
#  'Hiragino Sans',
#  'Heiti TC',
#  'Mukta Mahee',
#  'Trebuchet MS',
#  'Noto Sans Old Italic',
#  'DIN Condensed',
#  '.SF Compact',
#  'Arial Rounded MT Bold',
#  'STIXIntegralsUp',
#  'Avenir Next',
#  'Noto Sans Egyptian Hieroglyphs',
#  'Noto Sans Wancho',
#  'Telugu Sangam MN',
#  'Noto Sans Hanunoo',
#  'Noto Sans Vai',
#  'STIXIntegralsUp',
#  'Ayuthaya',
#  'Noto Sans Pahawh Hmong',
#  'Arial Narrow',
#  'Noto Sans Armenian',
#  'Wingdings 3',
#  'Oriya MN',
#  'Noto Sans Masaram Gondi',
#  'Times',
#  'Noto Sans Manichaean',
#  'InaiMathi']

# %%
print ('버전: ', mpl.__version__)
print ('설치 위치: ', mpl.__file__)
print ('설정 위치: ', mpl.get_configdir())
print ('캐시 위치: ', mpl.get_cachedir())
# Out:
# 버전:  3.5.1
# 설치 위치:  /Users/jinsuc28/miniforge3/lib/python3.9/site-packages/matplotlib/__init__.py
# 설정 위치:  /Users/jinsuc28/.matplotlib
# 캐시 위치:  /Users/jinsuc28/.matplotlib

# %%
rc('font', family='AppleGothic')
# rcdefaults()

# %% [markdown]
# # 분석 자료
#
# - 카테고리 따라서 매출 추이
# - 카테고리 따라서 강의 수 대비 매출
# - 카테고리에 따라서 쿠폰없이도 결재율이 어떻게 되는지

# %%
df.head()
# Out:
#        id  customer_id  course_id     type      state  \
# 0  970634     504760.0   201435.0    ORDER  CANCELLED
# 1  970650     432862.0   203178.0    ORDER  CANCELLED
# 2  970657      72297.0   204246.0  PAYMENT  COMPLETED
# 3  970656      72297.0   204246.0    ORDER  CANCELLED
# 4  970658     478028.0   201797.0  PAYMENT  COMPLETED
#
#                     course_title category_title  format        completed_at  \
# 0      올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍     올인원 2021-03-28 15:00:11
# 1    초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원 2021-03-28 15:16:53
# 2           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인 2021-03-28 15:21:43
# 3           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인 2021-03-28 15:21:43
# 4  올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원 2021-03-28 15:21:54
#
#    transaction_amount              coupon_title  coupon_discount_amount  \
# 0               90500                       NaN                     NaN
# 1               96000                       NaN                     NaN
# 2              171810     [10% 할인] 시크릿코드 실무 완성편                 19090.0
# 3              171810                       NaN                     NaN
# 4               97500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
#
#    sale_price  tax_free_amount   pg method subcategory_title  \
# 0    110500.0         110500.0  NaN  VBANK           개발자 커리어
# 1    116000.0         116000.0  NaN   CARD             영상 편집
# 2    190900.0         190900.0  NaN   CARD               NaN
# 3    190900.0         190900.0  NaN   CARD               NaN
# 4    117500.0         117500.0  NaN   CARD           PPT/보고서
#
#   marketing_start_at
# 0                NaT
# 1         2020-12-02
# 2         2021-03-04
# 3         2021-03-04
# 4         2019-11-14

# %%
df.state.unique()
# Out:
# array(['COMPLETED'], dtype=object)

# %%
# 구매완료한 강의만 
df = df[df.state=='COMPLETED']
# 데이터 사이언스 == 데이터사이언스 로 바꾸기
df.loc[df.category_title=='데이터 사이언스', 'category_title']= '데이터사이언스'
# payment만 남기고 나머지 전처리
df = df[df.type=='PAYMENT']

# %%
df.category_title.unique()
# Out:
# array(['프로그래밍', '업무 생산성', '영상/3D', '부동산/금융', '데이터사이언스', '디자인', '마케팅',
#        '크리에이티브', '투자/재테크', '교육', '관리', nan, '비즈니스', '지식콘텐츠', '파이낸스'],
#       dtype=object)

# %%
# 0원인 강의만 전처리
df = df[df.transaction_amount!=0]
# 10000원 이하인 강의만 전처리
# df = df[df.transaction_amount>10000]

# %%
df.describe()
# Out:
#                  id    customer_id      course_id  transaction_amount  \
# count  4.711300e+04   47113.000000   45134.000000        4.711300e+04
# mean   1.170013e+06  426292.508989  204014.226370        1.832947e+05
# std    1.169790e+05  210755.353207    1435.734673        9.313140e+05
# min    9.664500e+05      46.000000  200260.000000        1.020000e+04
# 25%    1.063860e+06  270523.000000  203178.000000        9.800000e+04
# 50%    1.171484e+06  510709.000000  203935.000000        1.260000e+05
# 75%    1.276775e+06  581648.000000  205053.000000        1.690000e+05
# max    1.381657e+06  672308.000000  207742.000000        1.134000e+08
#
#        coupon_discount_amount    sale_price  tax_free_amount
# count            19454.000000  4.604600e+04     4.604600e+04
# mean             36926.859515  1.612925e+05     1.587854e+05
# std              38200.829217  2.478542e+05     2.412446e+05
# min                500.000000  1.040000e+04     1.040000e+04
# 25%              20000.000000  1.120000e+05     1.120000e+05
# 50%              20000.000000  1.390000e+05     1.390000e+05
# 75%              34700.000000  1.730000e+05     1.730000e+05
# max             700000.000000  4.460000e+07     4.460000e+07

# %%
pd.DataFrame(df.category_title.value_counts(), df.category_title.value_counts().keys())
# Out:
#          category_title
# 프로그래밍             14171
# 데이터사이언스            6409
# 업무 생산성             6215
# 디자인                5329
# 영상/3D              4800
# 마케팅                4386
# 부동산/금융             2645
# 투자/재테크             1331
# 교육                  923
# 크리에이티브              840
# 비즈니스                 22
# 지식콘텐츠                21
# 파이낸스                 17
# 관리                    1

# %%
# 상위 10개 카테고리 별 강의 비율
# df.category_title.value_counts()

plt.figure(figsize=(8,8))

category_title = df.category_title.value_counts().head(10).keys()
values = df.category_title.value_counts().head(10).values

ratio = values
labels = category_title
explode = [0.05]*len(df.category_title.value_counts().head(10).keys())

plt.title('상위 10개 카테고리 강의 비율', fontsize=15)

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode)
plt.show()

# %%
# 카테고리 별 금액
# df.groupby('category_title').sum().loc[:,'transaction_amount'].sort_values(ascending=False)
plt.figure(figsize=(15,3))
x = np.arange(len(df.category_title.value_counts().keys()))
category_title = df.groupby('category_title').sum().loc[:,'transaction_amount'].sort_values(ascending=False).keys()
values = df.groupby('category_title').sum().loc[:,'transaction_amount'].sort_values(ascending=False).values

plt.bar(x, values)
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
plt.xticks(x, category_title)
plt.title('카테고리 별 총 매출', fontsize=15)


plt.show()

# %%
# 카테고리 별 판매 대비 금액
category_course_money = (df.groupby('category_title').sum().loc[:,'transaction_amount']//df.category_title.value_counts()).sort_values(ascending=False)
category_course_money
plt.figure(figsize=(15,3))
x = np.arange(len(df.category_title.value_counts().keys()))
category_title = category_course_money.keys()
values = category_course_money.values

plt.bar(x, values)
plt.xticks(x, category_title)
plt.title('카테고리 별 강의 당 가격', fontsize=15)

plt.show()

# %%
df.loc[df.category_title=='교육',['course_title','format','transaction_amount']].sort_values('transaction_amount', ascending=False).head(30)
# Out:
#                                           course_title   format  \
# 5299                    (B2B) 신용보증기금 온라인 구독 싱글 플랜 (1차)  B2B 온라인
# 100860                   (B2B) kt ds 온라인 구독 싱글 플랜 (8월)  B2B 온라인
# 23916                        (B2B) 우송대학교 온라인 구독 패키지 플랜  B2B 온라인
# 73268                         (B2B) KT 온라인 구독 올 플랜(추가)  B2B 온라인
# 36870                        (B2B) 오토닉스 온라인 구독 싱글/올 플랜  B2B 온라인
# 80285                        (B2B) (주)렉스코드 온라인 구독 올 플랜  B2B 온라인
# 42698                          (B2B) 한국리서치 온라인 구독 올 플랜  B2B 온라인
# 13053                         (B2B) 고려해운 온라인 구독 (4월입과)  B2B 온라인
# 24138                 (B2B) KB데이타시스템 온라인 구독 싱글 플랜 (4월)  B2B 온라인
# 13522                   (B2B) 제일기획 온라인 구독 싱글 플랜 (2021)  B2B 온라인
# 30990                    (B2B) kt ds 온라인 구독 싱글 플랜 (4월)  B2B 온라인
# 102991              (B2B) 롯데인재개발원 온라인 턴키 제휴 (2021년 8월)      B2B
# 91068                   (B2B) 신용보증기금 온라인 구독 싱글 플랜 (2차)  B2B 온라인
# 76342               (B2B) 롯데인재개발원 온라인 턴키 제휴 (2021년 6월)      B2B
# 86417                      (B2B) 포스코인재창조원 온라인 구독 싱글 플랜  B2B 온라인
# 28923           (B2B) 숙명여자대학교 미래경영 MBA 온라인 구독 ALL PLAN  B2B 온라인
# 10177                    (B2B) kt ds 온라인 구독 싱글 플랜 (3월)  B2B 온라인
# 92793                       (B2B) (주)이지엠앤씨 온라인 구독 올 플랜  B2B 온라인
# 86511                    (B2B) kt ds 온라인 구독 싱글 플랜 (7월)  B2B 온라인
# 6040                  (B2B) 씨제이올리브네트웍스 주식회사 온라인 구독 올플랜  B2B 온라인
# 92401                 (B2B) KB데이타시스템 온라인 구독 싱글 플랜 (8월)  B2B 온라인
# 59899                       (B2B) 에쓰오일 온라인 구독 ALL PLAN  B2B 온라인
# 77434                   (B2B) 한국관광공사 신입사원 온라인 구독 싱글 플랜  B2B 온라인
# 36096                      (B2B) 한라그룹 온라인 구독 싱글 플랜(5월)  B2B 온라인
# 71036                    (B2B) kt ds 온라인 구독 싱글 플랜 (5월)  B2B 온라인
# 59426   (B2B) 한국우편사업진흥원 온라인 구독 올 플랜/패키지 플랜 - 2021년 06월  B2B 온라인
# 13690                          (B2B) 토이트론 온라인 구독 싱글 플랜  B2B 온라인
# 26978                        (B2B) 웰컴저축은행 온라인 구독 싱글 플랜  B2B 온라인
# 87521                       (B2B) 서울교통공사 온라인 구독 패키지 플랜  B2B 온라인
# 44510                        (B2B) 지투알 온라인 구독 싱글 플랜 3차  B2B 온라인
#
#         transaction_amount
# 5299              19953975
# 100860            18672375
# 23916             15054000
# 73268             15000000
# 36870             14491480
# 80285             14449500
# 42698             14400000
# 13053             13836298
# 24138             13693925
# 13522             13303988
# 30990             11318600
# 102991            11305000
# 91068             10119420
# 76342              9250000
# 86417              9040000
# 28923              8640000
# 10177              8618670
# 92793              7800000
# 86511              7514370
# 6040               7410000
# 92401              6845475
# 59899              6840000
# 77434              6534000
# 36096              6273000
# 71036              5829660
# 59426              5610000
# 13690              5102280
# 26978              5075280
# 87521              4888800
# 44510              4700315

# %% [markdown]
# # 카테고리에 따라서 쿠폰없이도 결재율이 어떻게 되는지

# %%
# 쿠폰 적용 없는 강의 구매자
null_coupon = df[df.coupon_title.isnull()]
coupon = df[df.coupon_title.notnull()]

# %%
print('쿠폰 없이 결제:',len(null_coupon))
print('쿠폰 결제:',len(coupon))
print('전체 결제:',len(df))
# Out:
# 쿠폰 없이 결제: 27659
# 쿠폰 결제: 19454
# 전체 결제: 47113

# %%
# 쿠폰 없이 결제 수
null_coupon.groupby('category_title').count().loc[:,'customer_id'].sort_values(ascending=False)
# Out:
# category_title
# 프로그래밍      8489
# 업무 생산성     3897
# 데이터사이언스    3849
# 마케팅        3014
# 디자인        2381
# 영상/3D      2201
# 부동산/금융     1585
# 교육          923
# 크리에이티브      642
# 투자/재테크      617
# 지식콘텐츠        21
# 비즈니스         19
# 파이낸스         17
# 관리            1
# Name: customer_id, dtype: int64

# %%
# 쿠폰 결제 수
coupon.groupby('category_title').count().loc[:,'customer_id'].sort_values(ascending=False)
# Out:
# category_title
# 프로그래밍      5682
# 디자인        2948
# 영상/3D      2599
# 데이터사이언스    2560
# 업무 생산성     2318
# 마케팅        1372
# 부동산/금융     1060
# 투자/재테크      714
# 크리에이티브      198
# 비즈니스          3
# Name: customer_id, dtype: int64

# %%
category = []
for i in null_coupon.category_title.unique():
    if i not in coupon.category_title.unique():
        category.append(i)
print('쿠폰 없이만 결제 가능한 카테고리: ',category)
# Out:
# 쿠폰 없이만 결제 가능한 카테고리:  ['교육', '관리', nan, '지식콘텐츠', '파이낸스']

# %%
# 쿠폰 없이만 결제 가능한 카테고리 제외
null_coupon = null_coupon[((null_coupon['category_title'] != '교육')
             &(null_coupon['category_title'] != '관리')) 
            &(null_coupon['category_title'] != '지식콘텐츠')
            & (null_coupon['category_title'] != 'nan')
            & (null_coupon['category_title'] != '파이낸스')
           ]

# %%
labels = coupon.category_title.unique()
null = (null_coupon.groupby('category_title').count().loc[:,'customer_id'].sort_values(ascending=False)).values
notnull = (coupon.groupby('category_title').count().loc[:,'customer_id'].sort_values(ascending=False)).values

x = np.arange(len(labels),)
width = 0.3

# plt.figure(figsize=(20,3))
fig, ax = plt.subplots()
rects1 = ax.bar(x- width/2, null, width, label='쿠폰 미사용')
rects2 = ax.bar(x+ width/2, notnull, width, label='쿠폰 사용')

ax.set_xticks(x, labels)


ax.bar_label(rects1, padding=5)
ax.bar_label(rects2, padding=5)

fig.tight_layout()
plt.show()

# %%
# 쿠폰 상대도수 분포
relative_frequency = null_coupon.groupby('category_title').count().loc[:,'customer_id']/(null_coupon.groupby('category_title').count().loc[:,'customer_id']+coupon.groupby('category_title').count().loc[:,'customer_id'])
y = list(relative_frequency.keys())
x = relative_frequency.values

# 쿠폰 없이 구매 비율
pd.DataFrame(x,y,columns=['relative_frequency']).sort_values('relative_frequency',ascending=False)
# Out:
#          relative_frequency
# 비즈니스               0.863636
# 크리에이티브             0.764286
# 마케팅                0.687187
# 업무 생산성             0.627031
# 데이터사이언스            0.600562
# 부동산/금융             0.599244
# 프로그래밍              0.599040
# 투자/재테크             0.463561
# 영상/3D              0.458542
# 디자인                0.446801

# %%
null_coupon.groupby('category_title').count().loc[:,'customer_id']
# Out:
# category_title
# 데이터사이언스    3849
# 디자인        2381
# 마케팅        3014
# 부동산/금융     1585
# 비즈니스         19
# 업무 생산성     3897
# 영상/3D      2201
# 크리에이티브      642
# 투자/재테크      617
# 프로그래밍      8489
# Name: customer_id, dtype: int64

# %% [markdown]
# # 밑은 아닙니다!!

# %%
customers = df.customer_id.value_counts().loc[df.customer_id.value_counts()==1].index

# %%
df.loc[data.customer_id.isin(customers)]
# Out:
#              id  customer_id  course_id     type      state  \
# 4        970658     478028.0   201797.0  PAYMENT  COMPLETED
# 8        970669     478033.0   203178.0  PAYMENT  COMPLETED
# 10       970671     469860.0   203644.0  PAYMENT  COMPLETED
# 18       970682     478031.0        NaN  PAYMENT  COMPLETED
# 22       970695     455311.0   203146.0  PAYMENT  COMPLETED
# ...         ...          ...        ...      ...        ...
# 105408  1364956     545804.0        NaN  PAYMENT  COMPLETED
# 105411  1364969     669238.0   204286.0  PAYMENT  COMPLETED
# 105413  1364991     670891.0   203935.0  PAYMENT  COMPLETED
# 105416  1364996     640697.0   205365.0  PAYMENT  COMPLETED
# 105418  1365007     610626.0   206720.0  PAYMENT  COMPLETED
#
#                                           course_title category_title format  \
# 4                        올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성    올인원
# 8                          초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D    올인원
# 10      올인원 패키지 : 권오상의 금융 아카데미 - 권오상의 재무제표 분석 기초(평생소장)         부동산/금융    올인원
# 18               프로모션 : 기초부터 시작하는 데이터분석 한끝세트 (3월 프리패스)        데이터사이언스    올인원
# 22                         The RED : 현실 세상의 TDD by 이규원          프로그래밍    RED
# ...                                                ...            ...    ...
# 105408                프로모션 : 디자인 맥북 pro 패스(9월 현물 프리패스)            디자인    올인원
# 105411                      초격차 패키지 : 한번에 끝내는 3D 디자인 툴            디자인    올인원
# 105413                     초격차 패키지 : 한 번에 끝내는 파이썬 웹 개발          프로그래밍    올인원
# 105416                 초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기          영상/3D    올인원
# 105418                              용호수의 돈 버는 실전 영상 제작          영상/3D    올인원
#
#               completed_at  transaction_amount               coupon_title  \
# 4      2021-03-28 15:21:54               97500   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 8      2021-03-28 15:26:47               96000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 10     2021-03-28 15:27:17              263000                        NaN
# 18     2021-03-28 15:33:28              299000                        NaN
# 22     2021-03-28 15:43:59              149500                        NaN
# ...                    ...                 ...                        ...
# 105408 2021-09-25 13:25:49             1800000                        NaN
# 105411 2021-09-25 13:39:26              212000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 105413 2021-09-25 14:01:26              159000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 105416 2021-09-25 14:17:41               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰
# 105418 2021-09-25 14:25:47              139000  [WELCOME] 온라인 강의 3만원 할인쿠폰
#
#         coupon_discount_amount  sale_price  tax_free_amount      pg method  \
# 4                      20000.0    117500.0         117500.0     NaN   CARD
# 8                      20000.0    116000.0         116000.0     NaN   CARD
# 10                         NaN    263000.0         263000.0     NaN   CARD
# 18                         NaN    299000.0         299000.0     NaN   CARD
# 22                         NaN    149500.0         149500.0     NaN   CARD
# ...                        ...         ...              ...     ...    ...
# 105408                     NaN   1800000.0         295200.0  INICIS   CARD
# 105411                 20000.0    232000.0         232000.0  INICIS   CARD
# 105413                 20000.0    179000.0         179000.0  INICIS   CARD
# 105416                 20000.0    116000.0         116000.0  INICIS  VBANK
# 105418                 30000.0    169000.0         169000.0   NAVER  POINT
#
#        subcategory_title marketing_start_at
# 4                PPT/보고서         2019-11-14
# 8                  영상 편집         2020-12-02
# 10                   NaN         2020-11-27
# 18                   NaN                NaT
# 22                DevOps         2021-02-08
# ...                  ...                ...
# 105408               NaN                NaT
# 105411              디자인툴         2021-04-23
# 105413            백엔드 개발         2021-05-31
# 105416             영상 편집         2021-06-15
# 105418             영상 편집         2021-08-17
#
# [30897 rows x 18 columns]

# %%
df.state.unique()
# Out:
# array(['CANCELLED', 'COMPLETED', 'PENDING', 'DELETED', 'REQUESTED'],
#       dtype=object)

# %%
df.type.unique()
# Out:
# array(['ORDER', 'PAYMENT', 'REFUND', 'TRANSACTION'], dtype=object)

# %%
df.format.unique()
# Out:
# array(['올인원', '스쿨 온라인', '온라인 완주반', 'RED', 'B2B 온라인', '캠프', '스쿨', nan,
#        'B2B', '이벤트', '하루10분컷', '아카이브', '관리', '온라인', 'MBA', '콜로소', 'B2G'],
#       dtype=object)

# %%
data.category_title.unique()
# Out:
# array(['프로그래밍', '영상/3D', '업무 생산성', '크리에이티브', '부동산/금융', '데이터사이언스', '디자인',
#        '마케팅', '교육', '투자/재테크', nan, '관리', '데이터 사이언스', '비즈니스', '지식콘텐츠',
#        '일러스트', '파이낸스'], dtype=object)

# %%
data.method.unique()
# Out:
# array(['VBANK', 'CARD', 'TRANS', 'PROMOTION', 'TRANSFER', 'ONSITE',
#        'B2B_CONTRACT', nan, 'POINT', 'VOUCHER'], dtype=object)

# %%
data.pg.unique()
# Out:
# array([nan, 'INICIS', 'KAKAO', 'CHAI', 'PAYCO', 'NAVER'], dtype=object)

# %%
a = data.groupby('pg').max()
a
# Out:
# /var/folders/tb/j9qmrzv54k73r5l100jxqll80000gn/T/ipykernel_40216/4111141511.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   a = data.groupby('pg').max()
#              id  customer_id  course_id    type      state  \
# pg
# CHAI    1362936     669874.0   206814.0  REFUND  REQUESTED
# INICIS  1365005     670896.0   207729.0  REFUND  REQUESTED
# KAKAO   1364976     670817.0   207652.0  REFUND  REQUESTED
# NAVER   1365007     670735.0   207654.0  REFUND  COMPLETED
# PAYCO   1364862     670746.0   207563.0  REFUND    PENDING
#
#                 course_title  format        completed_at  transaction_amount  \
# pg
# CHAI    합격 패스 : 데이터베이스와 SQLD  하루10분컷 2021-09-24 02:06:33              640000
# INICIS  합격 패스 : 정보처리기사 필기&실기  하루10분컷 2021-09-25 14:19:56            90940000
# KAKAO   합격 패스 : 정보처리기사 필기&실기  하루10분컷 2021-09-25 13:46:29             1800000
# NAVER   합격 패스 : 정보처리기사 필기&실기  하루10분컷 2021-09-25 14:25:47            33797000
# PAYCO   합격 패스 : 정보처리기사 필기&실기  하루10분컷 2021-09-25 11:18:55             1800000
#
#         coupon_discount_amount  sale_price  tax_free_amount marketing_start_at
# pg
# CHAI                  148000.0    640000.0         640000.0         2021-09-13
# INICIS               1000000.0  90940000.0       90940000.0         2021-09-13
# KAKAO                 319000.0   1800000.0        1620000.0         2021-09-13
# NAVER                 321000.0  33797000.0       33797000.0         2021-09-13
# PAYCO                 319000.0   1800000.0        1800000.0         2021-09-13

# %%
print(len(data.customer_id), len(data.course_id))
# Out:
# 105419 105419

# %%
len((data.customer_id.unique()))
# Out:
# 53754

# %%
len((data.course_id.unique()))
# Out:
# 1348

# %%
# 강의 구매 빈도 순위 나열
data.customer_id.value_counts().head()
# Out:
# 98685.0     78
# 50769.0     62
# 40783.0     59
# 496508.0    54
# 427973.0    51
# Name: customer_id, dtype: int64

# %%
# 강의 구매 빈도 순위 나열
data.course_id.value_counts().head()
# Out:
# 203720.0    3257
# 203525.0    2756
# 203178.0    2541
# 204670.0    2132
# 204871.0    1636
# Name: course_id, dtype: int64

# %%
# 강의 구매 취소 안한 구매자만 데이터
data = data[data.state!='CANCELLED']

# %%
data.head()
# Out:
#         id  customer_id  course_id     type      state  \
# 2   970657      72297.0   204246.0  PAYMENT  COMPLETED
# 4   970658     478028.0   201797.0  PAYMENT  COMPLETED
# 8   970669     478033.0   203178.0  PAYMENT  COMPLETED
# 10  970671     469860.0   203644.0  PAYMENT  COMPLETED
# 14  970676     478035.0   203720.0  PAYMENT  COMPLETED
#
#                                       course_title category_title  format  \
# 2                             시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 4                    올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원
# 8                      초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# 10  올인원 패키지 : 권오상의 금융 아카데미 - 권오상의 재무제표 분석 기초(평생소장)         부동산/금융     올인원
# 14                     초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍     올인원
#
#           completed_at  transaction_amount              coupon_title  \
# 2  2021-03-28 15:21:43              171810     [10% 할인] 시크릿코드 실무 완성편
# 4  2021-03-28 15:21:54               97500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 8  2021-03-28 15:26:47               96000  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 10 2021-03-28 15:27:17              263000                       NaN
# 14 2021-03-28 15:31:01               91000  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
#
#     coupon_discount_amount  sale_price  tax_free_amount   pg method  \
# 2                  19090.0    190900.0         190900.0  NaN   CARD
# 4                  20000.0    117500.0         117500.0  NaN   CARD
# 8                  20000.0    116000.0         116000.0  NaN   CARD
# 10                     NaN    263000.0         263000.0  NaN   CARD
# 14                 20000.0    111000.0         111000.0  NaN   CARD
#
#    subcategory_title marketing_start_at
# 2                NaN         2021-03-04
# 4            PPT/보고서         2019-11-14
# 8              영상 편집         2020-12-02
# 10               NaN         2020-11-27
# 14          프론트엔드 개발         2021-02-02

# %%
print(len(data.customer_id.unique()), len(data.course_id.unique()))
# Out:
# 43071 1326
