# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# row 제한 없애기
# pd.set_option('display.max_rows', None)

import pandas as pd
df = pd.read_csv('pp2_FC.csv', index_col = 0)

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
font_location = '../NanumGothic.ttf'  #font 경로 설정
font_name = fm.FontProperties(fname=font_location).get_name()
plt.rc('font', family=font_name)

# %%
df
# Out:
#             id  customer_id  course_id     type      state  \
# 0       970658     478028.0   201797.0  PAYMENT  COMPLETED
# 1       970704     471759.0   204068.0  PAYMENT  COMPLETED
# 2       970703     478051.0   203499.0  PAYMENT  COMPLETED
# 3       970721     140846.0   202612.0  PAYMENT  COMPLETED
# 4       970740     474451.0   202883.0  PAYMENT  COMPLETED
# ...        ...          ...        ...      ...        ...
# 19394  1364855     503113.0   205879.0  PAYMENT  COMPLETED
# 19395  1364862     670463.0   202726.0  PAYMENT  COMPLETED
# 19396  1364883     670787.0   205687.0  PAYMENT  COMPLETED
# 19397  1364886     578540.0   202789.0  PAYMENT  COMPLETED
# 19398  1364919     670833.0   201582.0  PAYMENT  COMPLETED
#
#                                        course_title category_title format  \
# 0                     올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성    올인원
# 1                        올인원 패키지 : 마디아의 UX/UI 포트폴리오            디자인    올인원
# ...

# %%
len(df['customer_id'].unique())
# Out:
# 16477

# %%
print(19399/16477)
# Out:
# 1.1773381076652303

# %%
df["customer_id"] = df["customer_id"].astype(int)

# %%
df["course_id"].dropna()
# Out:
# 0        201797.0
# 1        204068.0
# 2        203499.0
# 3        202612.0
# 4        202883.0
#            ...
# 19394    205879.0
# 19395    202726.0
# 19396    205687.0
# 19397    202789.0
# 19398    201582.0
# Name: course_id, Length: 19398, dtype: float64

# %%
df = df[~df["course_id"].isnull()]

# %%
df
# Out:
#             id  customer_id  course_id     type      state  \
# 0       970658       478028   201797.0  PAYMENT  COMPLETED
# 1       970704       471759   204068.0  PAYMENT  COMPLETED
# 2       970703       478051   203499.0  PAYMENT  COMPLETED
# 3       970721       140846   202612.0  PAYMENT  COMPLETED
# 4       970740       474451   202883.0  PAYMENT  COMPLETED
# ...        ...          ...        ...      ...        ...
# 19394  1364855       503113   205879.0  PAYMENT  COMPLETED
# 19395  1364862       670463   202726.0  PAYMENT  COMPLETED
# 19396  1364883       670787   205687.0  PAYMENT  COMPLETED
# 19397  1364886       578540   202789.0  PAYMENT  COMPLETED
# 19398  1364919       670833   201582.0  PAYMENT  COMPLETED
#
#                                        course_title category_title format  \
# 0                     올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성    올인원
# 1                        올인원 패키지 : 마디아의 UX/UI 포트폴리오            디자인    올인원
# ...

# %%
df["course_id"] = df["course_id"].astype(int)
# Out:
# C:\Users\Jeongkpa\AppData\Local\Temp/ipykernel_2652/2324291617.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["course_id"] = df["course_id"].astype(int)

# %%
df
# Out:
#             id  customer_id  course_id     type      state  \
# 0       970658       478028     201797  PAYMENT  COMPLETED
# 1       970704       471759     204068  PAYMENT  COMPLETED
# 2       970703       478051     203499  PAYMENT  COMPLETED
# 3       970721       140846     202612  PAYMENT  COMPLETED
# 4       970740       474451     202883  PAYMENT  COMPLETED
# ...        ...          ...        ...      ...        ...
# 19394  1364855       503113     205879  PAYMENT  COMPLETED
# 19395  1364862       670463     202726  PAYMENT  COMPLETED
# 19396  1364883       670787     205687  PAYMENT  COMPLETED
# 19397  1364886       578540     202789  PAYMENT  COMPLETED
# 19398  1364919       670833     201582  PAYMENT  COMPLETED
#
#                                        course_title category_title format  \
# 0                     올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성    올인원
# 1                        올인원 패키지 : 마디아의 UX/UI 포트폴리오            디자인    올인원
# ...

# %%
df = df.pivot_table('subcategory_title', index = "course_id" , columns= 'customer_id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2652/652599712.py in <module>
# ----> 1 df = df.pivot_table('subcategory_title', index = "course_id" , columns= 'customer_id')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    7949         from pandas.core.reshape.pivot import pivot_table
#    7950
# -> 7951         return pivot_table(
#    7952             self,
#    7953             values=values,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      93         return table.__finalize__(data, method="pivot_table")
#      94
# ---> 95     table = __internal_pivot_table(
#      96         data,
# ...

# %%
df
