# %%
import pandas as pd
FC_df = pd.read_excel('../파이널프로젝트_RAW_210329_210926.xlsx')

# %%
cond = (FC_df.type == 'PAYMENT') & (FC_df.state == 'COMPLETED')
FC_df = FC_df[cond]

# %%
FC_df
# Out:
#              id  customer_id  course_id     type      state  \
# 2        970657      72297.0   204246.0  PAYMENT  COMPLETED
# 4        970658     478028.0   201797.0  PAYMENT  COMPLETED
# 8        970669     478033.0   203178.0  PAYMENT  COMPLETED
# 10       970671     469860.0   203644.0  PAYMENT  COMPLETED
# 14       970676     478035.0   203720.0  PAYMENT  COMPLETED
# ...         ...          ...        ...      ...        ...
# 105411  1364969     669238.0   204286.0  PAYMENT  COMPLETED
# 105412  1364976     384003.0   203178.0  PAYMENT  COMPLETED
# 105413  1364991     670891.0   203935.0  PAYMENT  COMPLETED
# 105416  1364996     640697.0   205365.0  PAYMENT  COMPLETED
# 105418  1365007     610626.0   206720.0  PAYMENT  COMPLETED
#
#                                           course_title category_title  format  \
# 2                                 시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 4                        올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원
# ...

# %%
a = FC_df.groupby('format').size()

# %%
a
# Out:
# format
# B2B          396
# B2B 온라인      977
# B2G          349
# MBA           23
# RED         3215
# 관리             1
# 스쿨          1026
# 스쿨 온라인       602
# 아카이브          31
# 온라인 완주반     1363
# 올인원        43476
# 이벤트           82
# 캠프            21
# 하루10분컷      1339
# dtype: int64

# %%
a.tolist()
# Out:
# [396, 977, 349, 23, 3215, 1, 1026, 602, 31, 1363, 43476, 82, 21, 1339]

# %%
a.index.tolist()
# Out:
# ['B2B',
#  'B2B 온라인',
#  'B2G',
#  'MBA',
#  'RED',
#  '관리',
#  '스쿨',
#  '스쿨 온라인',
#  '아카이브',
#  '온라인 완주반',
#  '올인원',
#  '이벤트',
#  '캠프',
#  '하루10분컷']

# %%
print(type(a))
# Out:
# <class 'pandas.core.series.Series'>

# %%
A = pd.DataFrame(a, columns=['cnt'])

# %%
A
# Out:
#            cnt
# format
# B2B        396
# B2B 온라인    977
# B2G        349
# MBA         23
# RED       3215
# 관리           1
# 스쿨        1026
# 스쿨 온라인     602
# 아카이브        31
# 온라인 완주반   1363
# 올인원      43476
# 이벤트         82
# 캠프          21
# 하루10분컷    1339

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
font_location = 'C:\Users\Jeongkpa\FC_PJT\나눔 글꼴\나눔고딕\NanumFontSetup_TTF_GOTHIC/NanumGothic.ttf'  #font 경로 설정
font_name = fm.FontProperties(fname=font_location).get_name()
plt.rc('font', family=font_name)
# Out:
#   File "C:\Users\Jeongkpa\AppData\Local\Temp/ipykernel_16948/2247401160.py", line 3
#     font_location = 'C:\Users\Jeongkpa\FC_PJT\나눔 글꼴\나눔고딕\NanumFontSetup_TTF_GOTHIC.ttf'  #font 경로 설정
#                                                                                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# format에서 관리는 단 1개이므로 분석 X
import seaborn as sns
sns.barplot(data = A, x = a.index.tolist(), y =a.tolist() )
# Out:
# <AxesSubplot:>
# C:\Users\Jeongkpa\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50728 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jeongkpa\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 46972 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jeongkpa\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jeongkpa\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jeongkpa\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
